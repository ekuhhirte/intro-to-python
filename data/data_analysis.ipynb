# %%
import faker

fake = faker.Faker()

print(fake.email())
print(fake.address())
print(fake.company())
# Out:
# gibsonlisa@example.com
# 3546 Herrera Squares
# Jonesland, ND 62744
# Boyer-Butler

# %%
# Create a user
import json #imports json so we can use the json dump

users = []  # list of users

for i in range(100000): #skips the inidices and just runs it ten thousand times
    user = {
        "username": fake.unique.user_name(),
        "name": fake.name(),
        "email": fake.email(),
        "address": fake.address(),
        "age": fake.random_int(min =18, max = 90)
    }
    users.append(user)

with open("users.json", "w") as file: #creates a file if it doesn't exist, if it does exist it overwrites it
    json.dump(users, file, indent=4) #indentation is set so it looks a bit better

#print(users)

# %%
# Create an ad campaign
# Start and end dates
# Target age demographic
# Currency
import random
from datetime import date, timedelta

def get_start_end_dates():
    duration = random.randint(1, 2*365)
    offset = random.randint(-365, 365)
    start = date.today() - timedelta(days=offset)
